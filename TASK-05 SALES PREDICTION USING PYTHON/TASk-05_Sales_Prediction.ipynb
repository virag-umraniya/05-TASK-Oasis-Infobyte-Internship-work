# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Advertising.csv')

# %% [markdown]
# # Basic Check

# %%
data
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
data.shape
# Out:
# (200, 5)

# %%
data.describe
# Out:
# <bound method NDFrame.describe of      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]>

# %%
data.info
# Out:
# <bound method DataFrame.info of      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]>

# %% [markdown]
# # Exploratory Analysis
# ## Step 1 - Univariate Analysis

# %%
# Analysing TV
sns.displot(x=data.TV, kde = True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Analysing Radio
sns.histplot(x=data.Radio, kde = True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Analysing Newspaper
sns.histplot(x = data.Newspaper, kde = True)
# Out:
# <Axes: xlabel='Newspaper', ylabel='Count'>

# %% [markdown]
# ## Step 2 - Bivariate Analysis

# %%
sns.relplot(x = data.TV, y = data.Sales, data = data)

# %%
plt.plot(data.TV)
plt.plot(data.Sales)

# %%
# Analysing radio and sale
sns.relplot(x = data.Radio, y = data.Sales, data = data)

# %%
sns.relplot(x = data.Newspaper, y = data.Sales, data = data)

# %% [markdown]
# ## Step 3 - Multivariate Analyzing

# %%
sns.pairplot(data)

# %% [markdown]
# ## Feature Engineering

# %%
# Step 1 - Finding missing values 
data.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
# Step 2 - Converting categorical data to numerical

# %%
# Step 3 - Checking the outliers
sns.boxplot(x = data.TV) # you should give x to make it horizontal
# Out:
# <Axes: xlabel='TV'>

# %%
sns.boxplot(x = data.Radio)
# Out:
# <Axes: xlabel='Radio'>

# %%
sns.boxplot(x = data.Newspaper)
# Out:
# <Axes: xlabel='Newspaper'>

# %% [markdown]
# ### There is outliers in newspaper

# %%
data.loc[(data.Newspaper >= 90)]
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 16           17   67.8   36.6      114.0   12.5
# 101         102  296.4   36.3      100.9   23.8

# %%
np.median(data)
# Out:
# 30.65

# %%
data.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
data.loc[data.Newspaper > 90] = np.median(data.Newspaper)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_16056\4226264539.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '25.75' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[data.Newspaper > 90] = np.median(data.Newspaper)

# %%
sns.boxplot(x = data.Newspaper)
# Out:
# <Axes: xlabel='Newspaper'>

# %% [markdown]
# ### From Below Feature Selection

# %%
# Step one dropping unwanted Features
data
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1.0  230.1   37.8       69.2   22.1
# 1           2.0   44.5   39.3       45.1   10.4
# 2           3.0   17.2   45.9       69.3    9.3
# 3           4.0  151.5   41.3       58.5   18.5
# 4           5.0  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195       196.0   38.2    3.7       13.8    7.6
# 196       197.0   94.2    4.9        8.1    9.7
# 197       198.0  177.0    9.3        6.4   12.8
# 198       199.0  283.6   42.0       66.2   25.5
# 199       200.0  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
data.drop('Unnamed: 0',axis = 1, inplace = True)

# %%
data
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
# Step 2 - Checking the Correlation
sns.heatmap(data.drop('Sales', axis = 1).corr(), annot = True)
# Out:
# <Axes: >

# %% [markdown]
# ## Model Creation

# %% [markdown]
# # Step 1 - Independent and dependent variable creation

# %%
X = data[['TV', 'Radio', 'Newspaper']] # X variable contains all input
y = data.Sales # Y contains output / Target

# %%
X
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %% [markdown]
# ## Model Selection

# %% [markdown]
# # Step 2 - Training and testing data creation

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train,y_test = train_test_split (X, y, test_size = 0.2, random_state = 33)

# %%
X_train
# Out:
#          TV  Radio  Newspaper
# 82    75.30  20.30      32.50
# 101   25.75  25.75      25.75
# 47   239.90  41.50      18.50
# 27   240.10  16.70      22.90
# 44    25.10  25.70      43.30
# ..      ...    ...        ...
# 57   136.20  19.20      16.60
# 146  240.10   7.30       8.70
# 66    31.50  24.60       2.20
# 135   48.30  47.00       8.50
# 20   218.40  27.70      53.40
#
# [160 rows x 3 columns]

# %%
X_test
# Out:
#         TV  Radio  Newspaper
# 15   195.4   47.7       52.9
# 171  164.5   20.9       47.4
# 103  187.9   17.2       17.9
# 119   19.4   16.0       22.3
# 116  139.2   14.3       25.6
# 162  188.4   18.1       25.6
# 54   262.7   28.8       15.9
# 17   281.4   39.6       55.8
# 117   76.4    0.8       14.8
# 100  222.4    4.3       49.8
# 109  255.4   26.9        5.5
# 8      8.6    2.1        1.0
# 118  125.7   36.9       79.2
# 38    43.1   26.7       35.1
# 29    70.6   16.0       40.8
# 149   44.7   25.8       20.6
# 81   239.8    4.1       36.9
# 126    7.8   38.9       50.6
# 189   18.7   12.1       23.4
# 85   193.2   18.4       65.7
# 197  177.0    9.3        6.4
# 152  197.6   23.3       14.2
# 50   199.8    3.1       34.6
# 62   239.3   15.5       27.3
# 92   217.7   33.5       59.0
# 34    95.7    1.4        7.4
# 153  171.3   39.7       37.7
# 14   204.1   32.9       46.0
# 91    28.6    1.5       33.0
# 173  168.4    7.1       12.8
# 199  232.1    8.6        8.7
# ...

# %%
X_test.shape
# Out:
# (40, 3)

# %%
y_train
# Out:
# 82     11.30
# 101    25.75
# 47     23.20
# 27     15.90
# 44      8.50
#        ...
# 57     13.20
# 146    13.20
# 66      9.50
# 135    11.60
# 20     18.00
# Name: Sales, Length: 160, dtype: float64

# %%
y_test
# Out:
# 15     22.4
# 171    14.5
# 103    14.7
# 119     6.6
# 116    12.2
# 162    14.9
# 54     20.2
# 17     24.4
# 117     9.4
# 100    11.7
# 109    19.8
# 8       4.8
# 118    15.9
# 38     10.1
# 29     10.5
# 149    10.1
# 81     12.3
# 126     6.6
# 189     6.7
# 85     15.2
# 197    12.8
# 152    16.6
# 50     11.4
# 62     15.7
# 92     19.4
# 34      9.5
# 153    19.0
# 14     19.0
# 91      7.3
# 173    11.7
# 199    13.4
# 177    11.7
# 141    19.2
# 125    10.6
# 89     16.7
# 75      8.7
# 71     12.4
# 195     7.6
# 182     8.7
# 112    14.1
# Name: Sales, dtype: float64

# %%
y_test.shape
# Out:
# (40,)

# %% [markdown]
# # step 3 Model Selection

# %%
from sklearn.linear_model import LinearRegression

# %%
LR = LinearRegression() # Object Creation

# %%
LR.fit(X_train, y_train) # Training of linear regression
# Out:
# LinearRegression()

# %%
y_predict = LR.predict(X_test)

# %%
y_test # actual values
# Out:
# 15     22.4
# 171    14.5
# 103    14.7
# 119     6.6
# 116    12.2
# 162    14.9
# 54     20.2
# 17     24.4
# 117     9.4
# 100    11.7
# 109    19.8
# 8       4.8
# 118    15.9
# 38     10.1
# 29     10.5
# 149    10.1
# 81     12.3
# 126     6.6
# 189     6.7
# 85     15.2
# 197    12.8
# 152    16.6
# 50     11.4
# 62     15.7
# 92     19.4
# 34      9.5
# 153    19.0
# 14     19.0
# 91      7.3
# 173    11.7
# 199    13.4
# 177    11.7
# 141    19.2
# 125    10.6
# 89     16.7
# 75      8.7
# 71     12.4
# 195     7.6
# 182     8.7
# 112    14.1
# Name: Sales, dtype: float64

# %%
y_predict # Values predicted by model
# Out:
# array([21.05992125, 14.48073339, 14.73936703,  7.25379481, 12.08167878,
#        14.94347722, 20.22794871, 23.17992104,  6.72718478, 13.72723993,
#        19.53312791,  4.05096721, 15.96787808, 10.378688  ,  9.47366442,
#        10.25927418, 14.42638648, 11.25923508,  6.46143025, 15.2425393 ,
#        12.71455058, 16.34752056, 12.50664776, 16.62754301, 19.24647763,
#         7.66929889, 18.44412558, 18.53262076,  4.82151722, 11.91917666,
#        14.95173579, 12.15247491, 18.59894605,  9.35396764, 17.39287962,
#        12.62289291, 10.82104331,  5.64918621,  6.82886624, 13.84886741])

# %% [markdown]
# ## Step 4 - Model Evaluation

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, root_mean_squared_error

# %%
mean_squared_error(y_test, y_predict)
# Out:
# 2.1393540789058547

# %%
r2_score(y_test, y_predict)
# Out:
# 0.9020872377132478

# %%
# calculation of adjusted r2 score
adjusted_r2 = 1-(1-0.90) * (40 - 1) / (40 - 3 - 1)
# adj_r2 = 1-[(1-r2)(n-1)/(n-k-1)] 
# where k = number of independent feature
adjusted_r2
# Out:
# 0.8916666666666667

# %%
import math
print(math.sqrt(mean_squared_error(y_test, y_predict))) # root mean squared error
# Out:
# 1.4626530958863262

# %%
print(mean_absolute_error(y_test, y_predict))
# Out:
# 0.9993390598879242

# %%
root_mean_squared_error(y_test, y_predict)
# Out:
# 1.4626530958863262

# %%
LR.predict([[20, 2, 50]])
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([4.56338825])

# %%
import pickle

# %%
with open('model.pkl', 'wb') as file:
    pickle.dump(LR, file)

# %%
with open('model.pkl', 'rb') as file:
    model = pickle.load(file)

# %%
model.predict([[20000, 4000, 5000]])
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1651.25401999])
